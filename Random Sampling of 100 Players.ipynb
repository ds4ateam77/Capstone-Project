# %%
import pandas as pd

raw_data = pd.read_csv('2020-2021 NBA Player Stats.csv')

# %%
raw_data.head()
# Out:
#    Rk                       Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1   Precious Achiuwa\achiupr01  PF   21  MIA  61   4   737  124  228  ...
# 1   2       Jaylen Adams\adamsja01  PG   24  MIL   7   0    18    1    8  ...
# 2   3       Steven Adams\adamsst01   C   27  NOP  58  58  1605  189  308  ...
# 3   4        Bam Adebayo\adebaba01   C   23  MIA  64  64  2143  456  800  ...
# 4   5  LaMarcus Aldridge\aldrila01   C   35  TOT  26  23   674  140  296  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.509   73  135  208   29   20   28   43   91   304
# 1    NaN    0    3    3    2    0    0    0    1     2
# 2  0.444  213  301  514  111   54   38   78  113   438
# 3  0.799  142  431  573  346   75   66  169  145  1197
# 4  0.872   19   99  118   49   11   29   27   47   352
#
# [5 rows x 30 columns]

# %%
raw_data.shape
# Out:
# (705, 30)

# %%
raw_data['Player'].value_counts()
# Out:
# Norvel Pelle\pelleno01        4
# Rodions Kurucs\kurucro01      4
# Gary Clark\clarkga01          4
# Ignas Brazdeikis\brazdig01    4
# Damian Jones\jonesda03        4
#                              ..
# Frank Mason III\masonfr01     1
# Nate Darling\darlina01        1
# Chuma Okeke\okekech01         1
# Reggie Jackson\jacksre01      1
# Goran Dragić\dragigo01        1
# Name: Player, Length: 540, dtype: int64

# %%
raw_data['Player'] = raw_data['Player'].str.split(pat= '\\', expand = True)[0]

# %%
raw_data['Player'].value_counts()
# Out:
# Moritz Wagner       4
# Ignas Brazdeikis    4
# Gary Clark          4
# Rodions Kurucs      4
# Damian Jones        4
#                    ..
# Steven Adams        1
# Taj Gibson          1
# De'Aaron Fox        1
# Jordan Clarkson     1
# Anthony Gill        1
# Name: Player, Length: 540, dtype: int64

# %%
raw_data['Player'].unique()
# Out:
# array(['Precious Achiuwa', 'Jaylen Adams', 'Steven Adams', 'Bam Adebayo',
#        'LaMarcus Aldridge', 'Ty-Shon Alexander',
#        'Nickeil Alexander-Walker', 'Grayson Allen', 'Jarrett Allen',
#        'Al-Farouq Aminu', 'Kyle Anderson', 'Giannis Antetokounmpo',
#        'Kostas Antetokounmpo', 'Thanasis Antetokounmpo',
#        'Carmelo Anthony', 'Cole Anthony', 'OG Anunoby',
#        'Ryan Arcidiacono', 'Trevor Ariza', 'D.J. Augustin', 'Deni Avdija',
#        'Deandre Ayton', 'Udoka Azubuike', 'Dwayne Bacon',
#        'Marvin Bagley III', 'LaMelo Ball', 'Lonzo Ball', 'Mo Bamba',
#        'Desmond Bane', 'Harrison Barnes', 'RJ Barrett', 'Will Barton',
#        'Keita Bates-Diop', 'Nicolas Batum', 'Aron Baynes',
#        'Kent Bazemore', 'Darius Bazley', 'Bradley Beal', 'Malik Beasley',
#        'Jordan Bell', "DeAndre' Bembry", 'Dāvis Bertāns',
#        'Patrick Beverley', 'Saddiq Bey', 'Tyler Bey', 'Khem Birch',
#        'Goga Bitadze', 'Bismack Biyombo', 'Nemanja Bjelica',
# ...

# %%
raw_data_sample = raw_data['Player'].sample(100, random_state=77)

# %%
raw_data_sample.head(30)
# Out:
# 601              Jalen Smith
# 625              Matt Thomas
# 20           Carmelo Anthony
# 368             John Konchar
# 139               Tyler Cook
# 77              Tony Bradley
# 517             Norvel Pelle
# 17     Giannis Antetokounmpo
# 279             Jaxson Hayes
# 100            Jalen Brunson
# 120              Alex Caruso
# 83          Ignas Brazdeikis
# 493           Victor Oladipo
# 477          Frank Ntilikina
# 480             Jusuf Nurkić
# 247                 Kyle Guy
# 516             Norvel Pelle
# 334               Isaiah Joe
# 252                Josh Hall
# 205            Trent Forrest
# 148              Jae Crowder
# 549                Paul Reed
# 291             Jaylen Hoard
# 125               Gary Clark
# 323           Justin Jackson
# 272       Shaquille Harrison
# 219           Darius Garland
# 110         Facundo Campazzo
# 617             Daniel Theis
# 532       Kristaps Porziņģis
# Name: Player, dtype: object

# %%
raw_data.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')
