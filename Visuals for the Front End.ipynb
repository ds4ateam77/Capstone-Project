# %% [markdown]
# # Visuals for Front End Design

# %%
# !pip install dash

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go

# %%
import seaborn as sns
import pingouin
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statsmodels.formula.api as sm

# %%
import plotly.express as px
from textwrap import wrap

named_colorscales = px.colors.named_colorscales()
print("\n".join(wrap("".join('{:<12}'.format(c) for c in named_colorscales), 96)))
# Out:
# aggrnyl     agsunset    blackbody   bluered     blues       blugrn      bluyl       brwnyl
# bugn        bupu        burg        burgyl      cividis     darkmint    electric    emrld
# gnbu        greens      greys       hot         inferno     jet         magenta     magma
# mint        orrd        oranges     oryel       peach       pinkyl      plasma      plotly3
# pubu        pubugn      purd        purp        purples     purpor      rainbow     rdbu
# rdpu        redor       reds        sunset      sunsetdark  teal        tealgrn     turbo
# viridis     ylgn        ylgnbu      ylorbr      ylorrd      algae       amp         deep
# dense       gray        haline      ice         matter      solar       speed       tempo
# thermal     turbid      armyrose    brbg        earth       fall        geyser      prgn
# piyg        picnic      portland    puor        rdgy        rdylbu      rdylgn      spectral
# ...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Basketball Player Salaries and Endorsements

# %%
#import file
import io
player_salaries = pd.read_csv("Player_Salaries.csv")
player_salaries
# Out:
#     Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 0                                                 Item
# 1                                 Atlanta Hawks (2015)
# 2                                Boston Celtics (2002)
# 3                                 Brooklyn Nets (2019)
# 4                             Charlotte Hornets (2010)
# ..                                                 ...
# 394                             Minnesota Timberwolves
# 395                              Oklahoma City Thunder
# 396                                         Miami Heat
# 397                             Portland Trail Blazers
# 398  Source: Spotrac (NBA, Cap, Cap Space, Professi...
#
#      Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
#select the rows in each table that we're interested in. I'm pulling the top 10 Basketball Players Salaries: 

top10_players = player_salaries.iloc[48:58]
top10_players.reset_index()
top10_players
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 48                  LeBron James (Los Angeles Lakers)
# 49              Stephen Curry (Golden State Warriors)
# 50                       Kevin Durant (Brooklyn Nets)
# 51             Russell Westbrook (Washington Wizards)
# 52                       James Harden (Brooklyn Nets)
# 53            Giannis Antetokounmpo (Milwaukee Bucks)
# 54              Klay Thompson (Golden State Warriors)
# 55                       Kyrie Irving (Brooklyn Nets)
# 56                          Chris Paul (Phoenix Suns)
# 57            Damian Lillard (Portland Trail Blazers)
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 48         NaN         NaN         NaN         NaN         NaN         NaN
# 49         NaN         NaN         NaN         NaN         NaN         NaN
# 50         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Dropping the columns having NaN/NaT values
top10_players = top10_players.dropna(axis=1)
  
top10_players
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 48                  LeBron James (Los Angeles Lakers)
# 49              Stephen Curry (Golden State Warriors)
# 50                       Kevin Durant (Brooklyn Nets)
# 51             Russell Westbrook (Washington Wizards)
# 52                       James Harden (Brooklyn Nets)
# 53            Giannis Antetokounmpo (Milwaukee Bucks)
# 54              Klay Thompson (Golden State Warriors)
# 55                       Kyrie Irving (Brooklyn Nets)
# 56                          Chris Paul (Phoenix Suns)
# 57            Damian Lillard (Portland Trail Blazers)
#
#      Unnamed: 11
# 48  $31,400,000
# 49  $34,000,000
# 50  $31,200,000
# 51  $33,000,000
# 52  $33,000,000
# 53  $22,000,000
# 54  $28,300,000
# 55  $26,000,000
# 56  $33,100,000
# 57  $25,000,000

# %%
top10_players.reset_index()
# Out:
#    index  \
# 0     48
# 1     49
# 2     50
# 3     51
# 4     52
# 5     53
# 6     54
# 7     55
# 8     56
# 9     57
#
#   Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 0                  LeBron James (Los Angeles Lakers)
# 1              Stephen Curry (Golden State Warriors)
# 2                       Kevin Durant (Brooklyn Nets)
# 3             Russell Westbrook (Washington Wizards)
# 4                       James Harden (Brooklyn Nets)
# 5            Giannis Antetokounmpo (Milwaukee Bucks)
# 6              Klay Thompson (Golden State Warriors)
# 7                       Kyrie Irving (Brooklyn Nets)
# 8                          Chris Paul (Phoenix Suns)
# 9            Damian Lillard (Portland Trail Blazers)
#
#     Unnamed: 11
# 0  $31,400,000
# 1  $34,000,000
# 2  $31,200,000
# 3  $33,000,000
# 4  $33,000,000
# 5  $22,000,000
# 6  $28,300,000
# 7  $26,000,000
# 8  $33,100,000
# 9  $25,000,000

# %%
#add column names
top10_players.columns= ["players", "salaries in 2021" ]
top10_players
# Out:
#                                     players salaries in 2021
# 48        LeBron James (Los Angeles Lakers)     $31,400,000
# 49    Stephen Curry (Golden State Warriors)     $34,000,000
# 50             Kevin Durant (Brooklyn Nets)     $31,200,000
# 51   Russell Westbrook (Washington Wizards)     $33,000,000
# 52             James Harden (Brooklyn Nets)     $33,000,000
# 53  Giannis Antetokounmpo (Milwaukee Bucks)     $22,000,000
# 54    Klay Thompson (Golden State Warriors)     $28,300,000
# 55             Kyrie Irving (Brooklyn Nets)     $26,000,000
# 56                Chris Paul (Phoenix Suns)     $33,100,000
# 57  Damian Lillard (Portland Trail Blazers)     $25,000,000

# %%
#select the rows in each table that we're interested in. I'm pulling the top 10 Basketball Players Salaries plus endorsements: 

players_earnings = player_salaries.iloc[37:47]
players_earnings.reset_index()
players_earnings
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 37                  LeBron James (Los Angeles Lakers)
# 38              Stephen Curry (Golden State Warriors)
# 39                       Kevin Durant (Brooklyn Nets)
# 40             Russell Westbrook (Washington Wizards)
# 41                       James Harden (Brooklyn Nets)
# 42            Giannis Antetokounmpo (Milwaukee Bucks)
# 43              Klay Thompson (Golden State Warriors)
# 44                       Kyrie Irving (Brooklyn Nets)
# 45                          Chris Paul (Phoenix Suns)
# 46             Damian Lillard (Portland Trailblazers)
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 37         NaN         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Dropping the columns having NaN/NaT values
players_earnings = players_earnings.dropna(axis=1)
  
players_earnings
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 37                  LeBron James (Los Angeles Lakers)
# 38              Stephen Curry (Golden State Warriors)
# 39                       Kevin Durant (Brooklyn Nets)
# 40             Russell Westbrook (Washington Wizards)
# 41                       James Harden (Brooklyn Nets)
# 42            Giannis Antetokounmpo (Milwaukee Bucks)
# 43              Klay Thompson (Golden State Warriors)
# 44                       Kyrie Irving (Brooklyn Nets)
# 45                          Chris Paul (Phoenix Suns)
# 46             Damian Lillard (Portland Trailblazers)
#
#      Unnamed: 11
# 37  $95,400,000
# 38  $74,400,000
# 39  $65,200,000
# 40  $58,000,000
# 41  $50,000,000
# 42  $49,000,000
# 43  $43,300,000
# 44  $43,000,000
# 45  $40,100,000
# 46  $39,000,000

# %%
#add column names
players_earnings.columns= ["players", "Total Earnings in 2021" ]
players_earnings
# Out:
#                                     players Total Earnings in 2021
# 37        LeBron James (Los Angeles Lakers)           $95,400,000
# 38    Stephen Curry (Golden State Warriors)           $74,400,000
# 39             Kevin Durant (Brooklyn Nets)           $65,200,000
# 40   Russell Westbrook (Washington Wizards)           $58,000,000
# 41             James Harden (Brooklyn Nets)           $50,000,000
# 42  Giannis Antetokounmpo (Milwaukee Bucks)           $49,000,000
# 43    Klay Thompson (Golden State Warriors)           $43,300,000
# 44             Kyrie Irving (Brooklyn Nets)           $43,000,000
# 45                Chris Paul (Phoenix Suns)           $40,100,000
# 46   Damian Lillard (Portland Trailblazers)           $39,000,000

# %% [markdown]
# ##Player Earnings with Endorsements

# %%
#select the rows in each table that we're interested in. I'm pulling the top 10 Basketball Players endorsements: 

players_endorsements = player_salaries.iloc[59:69]
players_endorsements.reset_index()
players_endorsements
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 59                  Lebron James (Los Angeles Lakers)
# 60               Stephen Curry (Golden State Warriors
# 61                       Kevin Durant (Brooklyn Nets)
# 62             Russell Westbrook (Washington Wizards)
# 63                       James Harden (Brooklyn Nets)
# 64            Giannis Antetokounmpo (Milwaukee Bucks)
# 65              Klay Thompson (Golden State Warriors)
# 66                       Kyrie Irving (Brooklyn Nets)
# 67                          Chris Paul (Phoenix Suns)
# 68            Damian Lillard (Portland Trail Blazers)
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 59         NaN         NaN         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Dropping the columns having NaN/NaT values
players_endorsements = players_endorsements.dropna(axis=1)
  
players_endorsements
# Out:
#    Basketball: NBA - Purchase Price of each Franchise, year purchased ()  \
# 59                  Lebron James (Los Angeles Lakers)
# 60               Stephen Curry (Golden State Warriors
# 61                       Kevin Durant (Brooklyn Nets)
# 62             Russell Westbrook (Washington Wizards)
# 63                       James Harden (Brooklyn Nets)
# 64            Giannis Antetokounmpo (Milwaukee Bucks)
# 65              Klay Thompson (Golden State Warriors)
# 66                       Kyrie Irving (Brooklyn Nets)
# 67                          Chris Paul (Phoenix Suns)
# 68            Damian Lillard (Portland Trail Blazers)
#
#      Unnamed: 11
# 59  $64,000,000
# 60  $40,000,000
# 61  $34,000,000
# 62  $25,000,000
# 63  $17,000,000
# 64  $27,000,000
# 65  $15,000,000
# 66  $17,000,000
# 67   $7,000,000
# 68  $14,000,000

# %%
#add column names
players_endorsements.columns= ["Players", "Endorsements Earnings in 2021" ]
players_endorsements
# Out:
#                                     Players Endorsements Earnings in 2021
# 59        Lebron James (Los Angeles Lakers)                  $64,000,000
# 60     Stephen Curry (Golden State Warriors                  $40,000,000
# 61             Kevin Durant (Brooklyn Nets)                  $34,000,000
# 62   Russell Westbrook (Washington Wizards)                  $25,000,000
# 63             James Harden (Brooklyn Nets)                  $17,000,000
# 64  Giannis Antetokounmpo (Milwaukee Bucks)                  $27,000,000
# 65    Klay Thompson (Golden State Warriors)                  $15,000,000
# 66             Kyrie Irving (Brooklyn Nets)                  $17,000,000
# 67                Chris Paul (Phoenix Suns)                   $7,000,000
# 68  Damian Lillard (Portland Trail Blazers)                  $14,000,000

# %%
players_salaries_endorsements = top10_players

# %%
top10_players.head()
# Out:
#                                    players salaries in 2021
# 48       LeBron James (Los Angeles Lakers)     $31,400,000
# 49   Stephen Curry (Golden State Warriors)     $34,000,000
# 50            Kevin Durant (Brooklyn Nets)     $31,200,000
# 51  Russell Westbrook (Washington Wizards)     $33,000,000
# 52            James Harden (Brooklyn Nets)     $33,000,000

# %%
players_salaries_endorsements['Endorsements Earnings in 2021'] = players_endorsements['Endorsements Earnings in 2021']
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[0] = '$64,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[1] = '$40,000,000'

players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]] = players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]].apply(lambda x: x.str.replace(',', ''), axis=1).apply(lambda x: x.str.replace('$', ''), axis=1).apply(lambda x: x.astype(float), axis=1)
# Out:
# <ipython-input-172-a6ecc8b7e6de>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/daniellesmith/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-172-a6ecc8b7e6de>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
players_salaries_endorsements['Endorsements Earnings in 2021'] = players_endorsements['Endorsements Earnings in 2021']
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[0] = '$64,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[1] = '$40,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[2] = '$34,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[3] = '$25,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[4] = '$17,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[5] = '$27,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[6] = '$15,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[7] = '$17,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[8] = '$7,000,000'
players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[9] = '$14,000,000'
# Out:
# <ipython-input-173-fbf5aa61fcb0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-173-fbf5aa61fcb0>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-173-fbf5aa61fcb0>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-173-fbf5aa61fcb0>:4: SettingWithCopyWarning:
#
#
# ...

# %%
players_salaries_endorsements['salaries in 2021'] = top10_players['salaries in 2021']
players_salaries_endorsements['salaries in 2021'].iloc[0] = '$31,400,000'
players_salaries_endorsements['salaries in 2021'].iloc[1] = '$34,000,000'
players_salaries_endorsements['salaries in 2021'].iloc[2] = '$31,200,000'
players_salaries_endorsements['salaries in 2021'].iloc[3] = '$33,000,000'
players_salaries_endorsements['salaries in 2021'].iloc[4] = '$33,000,000'
players_salaries_endorsements['salaries in 2021'].iloc[5] = '$22,000,000'
players_salaries_endorsements['salaries in 2021'].iloc[6] = '$28,300,000'
players_salaries_endorsements['salaries in 2021'].iloc[7] = '$26,000,000'
players_salaries_endorsements['salaries in 2021'].iloc[8] = '$33,100,000'
players_salaries_endorsements['salaries in 2021'].iloc[9] = '$25,000,000'
# Out:
# <ipython-input-174-2c0a050d5d5d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-174-2c0a050d5d5d>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-174-2c0a050d5d5d>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-174-2c0a050d5d5d>:4: SettingWithCopyWarning:
#
#
# ...

# %%
players_salaries_endorsements.head(10)
# Out:
#                                     players salaries in 2021  \
# 48        LeBron James (Los Angeles Lakers)      $31,400,000
# 49    Stephen Curry (Golden State Warriors)      $34,000,000
# 50             Kevin Durant (Brooklyn Nets)      $31,200,000
# 51   Russell Westbrook (Washington Wizards)      $33,000,000
# 52             James Harden (Brooklyn Nets)      $33,000,000
# 53  Giannis Antetokounmpo (Milwaukee Bucks)      $22,000,000
# 54    Klay Thompson (Golden State Warriors)      $28,300,000
# 55             Kyrie Irving (Brooklyn Nets)      $26,000,000
# 56                Chris Paul (Phoenix Suns)      $33,100,000
# 57  Damian Lillard (Portland Trail Blazers)      $25,000,000
#
#    Endorsements Earnings in 2021
# 48                   $64,000,000
# 49                   $40,000,000
# 50                   $34,000,000
# 51                   $25,000,000
# 52                   $17,000,000
# 53                   $27,000,000
# 54                   $15,000,000
# ...

# %%
players_salaries_endorsements["salaries in 2021"] = pd.to_numeric(players_salaries_endorsements["salaries in 2021"])
# Out:
# <ipython-input-177-77322f2ca104>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
players_salaries_endorsements["Endorsements Earnings in 2021"] = pd.to_numeric(players_salaries_endorsements["Endorsements Earnings in 2021"])
# Out:
# <ipython-input-178-6f9fbb69c9e6>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#import plotly.express as px
#players_salaries_endorsements = top10_players
#players_salaries_endorsements['Endorsements Earnings in 2021'] = players_endorsements['Endorsements Earnings in 2021']
#players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[0] = '$64,000,000'
#players_salaries_endorsements['Endorsements Earnings in 2021'].iloc[1] = '$40,000,000'
players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]] = players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]].apply(lambda x: x.str.replace(',', ''), axis=1).apply(lambda x: x.str.replace('$', ''), axis=1).apply(lambda x: x.astype(float), axis=1)
# Out:
# /Users/daniellesmith/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.bar(players_salaries_endorsements, x='players',y=['salaries in 2021','Endorsements Earnings in 2021']
             ,title= 'Player Earnings in 2021'
            
             ,barmode = 'stack')
 
fig.show()
# Out:
# <div>                            <div id="c140b289-05d0-46e2-8bd5-e5cc99f151c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c140b289-05d0-46e2-8bd5-e5cc99f151c9")) {                    Plotly.newPlot(                        "c140b289-05d0-46e2-8bd5-e5cc99f151c9",                        [{"alignmentgroup":"True","hovertemplate":"variable=salaries in 2021<br>players=%{x}<br>value=%{y}<extra></extra>","legendgroup":"salaries in 2021","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"salaries in 2021","offsetgroup":"salaries in 2021","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["LeBron James (Los Angeles Lakers)","Stephen Curry (Golden State Warriors)","Kevin Durant (Brooklyn Nets)","Russell Westbrook (Washin
# ...

# %% [markdown]
# # Fan_Market_Summary

# %%
# create dataframe with imported file
import io
fan_market_summary = pd.read_csv('Fan_Market_Summary.csv')
fan_market_summary
# Out:
#                                                                         \
# 0                   Basketball: NBA Fan Market Summary     NaN     NaN
# 1                                                  NaN     NaN     NaN
# 2                                                 Item  2010.0    2011
# 3           --------------------TOTAL NBA FANS/AVIDITY     NaN     NaN
# 4    Total Number of NBA Fans Age 13+ (View and/or ...     NaN  77,794
# ..                                                 ...     ...     ...
# 266                                                NaN     NaN     NaN
# 267                                                NaN     NaN     NaN
# 268                                                NaN     NaN     NaN
# 269                                                NaN     NaN     NaN
# 270                                                NaN     NaN     NaN
#
#                                                                                \
# ...

# %%
#rename columns to organize data
fan_market_summary.columns = ['label', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'm']
fan_market_summary
# Out:
#                                                  label    2010    2011  \
# 0                   Basketball: NBA Fan Market Summary     NaN     NaN
# 1                                                  NaN     NaN     NaN
# 2                                                 Item  2010.0    2011
# 3           --------------------TOTAL NBA FANS/AVIDITY     NaN     NaN
# 4    Total Number of NBA Fans Age 13+ (View and/or ...     NaN  77,794
# ..                                                 ...     ...     ...
# 266                                                NaN     NaN     NaN
# 267                                                NaN     NaN     NaN
# 268                                                NaN     NaN     NaN
# 269                                                NaN     NaN     NaN
# 270                                                NaN     NaN     NaN
#
#        2012    2013    2014    2015    2016    2017    2018    2019    2020  \
# ...

# %%
#drop rows that contain all null values and m column
fan_market_summary = fan_market_summary.dropna(how='all')
fan_market_summary = fan_market_summary.drop(columns='m')
fan_market_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 248
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   244 non-null    object
#  1   2010    3 non-null      float64
#  2   2011    57 non-null     object
#  3   2012    164 non-null    object
#  4   2013    166 non-null    object
#  5   2014    168 non-null    object
#  6   2015    169 non-null    object
#  7   2016    166 non-null    object
#  8   2017    179 non-null    object
#  9   2018    186 non-null    object
#  10  2019    194 non-null    object
#  11  2020    188 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 24.8+ KB

# %%
#drop 2010 column because it contains no data
fan_market_summary['2010'].value_counts()
fan_market_summary = fan_market_summary.drop(columns='2010')

# %%
#create total_fans sub-table
total_fans = fan_market_summary.iloc[3:18]
total_fans
# Out:
#                                                 label    2011    2012    2013  \
# 4   Total Number of NBA Fans Age 13+ (View and/or ...  77,794  85,556  74,187
# 5              Total Number Attending Games (add 000)  13,758  11,386  12,662
# 6         % of Attendees who Attended More Than 1/yr.   50.7%   46.3%   42.4%
# 7            % of Attendees who Attended 4+ Times/yr.   24.9%   12.5%   15.5%
# 8   Total Viewed at Least One Game on TV and/or On...  73,938  82,046  69,719
# 9                Total Number Viewing on TV (add 000)  73,003  80,967  68,451
# 10         % of TV Viewers who Viewed More Than 2/yr.   87.5%   79.8%   80.1%
# 11           % of TV Viewers who Viewed 16+ Times/yr.   24.3%   22.4%   23.7%
# 12  Number of TV Viewers Viewed at Least One Game ...     NaN     NaN     NaN
# 13  Number of TV Viewers Who Streamed at Least One...     NaN     NaN     NaN
# 14  % of all TV Viewers Who Streamed at Least One ...     NaN     NaN     NaN
# ...

# %%
#create function to clean sub-tables
def clean_set(data):
    data = data.dropna(subset=['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'], how='all')
    data = data.replace('---', np.nan)
    data = data.apply(lambda x: x.str.replace(',', ''), axis=1)
    data = data.apply(lambda x: x.str.replace('%', ''), axis=1)
    data = data.apply(lambda x: x.str.replace('$', ''), axis=1)
    data.index = data['label']
    data = data.drop(columns='label')
    data = data.apply(lambda x: x.astype(float), axis=1)
    return data

# %%
#clean total_fans
total_fans = clean_set(total_fans)
total_fans
# Out:
#                                                        2011     2012     2013  \
# label
# Total Number of NBA Fans Age 13+ (View and/or A...  77794.0  85556.0  74187.0
# Total Number Attending Games (add 000)              13758.0  11386.0  12662.0
#  of Attendees who Attended More Than 1/yr.             50.7     46.3     42.4
#  of Attendees who Attended 4+ Times/yr.                24.9     12.5     15.5
# Total Viewed at Least One Game on TV and/or Onl...  73938.0  82046.0  69719.0
# Total Number Viewing on TV (add 000)                73003.0  80967.0  68451.0
#  of TV Viewers who Viewed More Than 2/yr.              87.5     79.8     80.1
#  of TV Viewers who Viewed 16+ Times/yr.                24.3     22.4     23.7
# Number of TV Viewers Viewed at Least One Game T...      NaN      NaN      NaN
# Number of TV Viewers Who Streamed at Least One ...      NaN      NaN      NaN
#  of all TV Viewers Who Streamed at Least One Ga...      NaN      NaN      NaN
# ...

# %%
#create and clean fan_demograpics the sub-table
fan_demographics = fan_market_summary.iloc[19:48]
fan_demographics = clean_set(fan_demographics)
fan_demographics
# Out:
#                                                      2011   2012   2013  \
# label
# 13-17                                                 9.8    9.0    7.8
# 18-34                                                31.4   26.3   30.6
# 35-49                                                26.0   22.4   21.8
# 50-64                                                25.2   24.9   22.3
# 65+                                                   7.6   17.5   17.6
# Total                                               100.0  100.0  100.0
# Generation Z (13-22)                                  NaN    NaN    NaN
# Millennials (23-38)                                   NaN    NaN    NaN
# Generation X (39-54)                                  NaN    NaN    NaN
# Boomers (55-73)                                       NaN    NaN    NaN
# Total (less than 100 because ages 74+ not inclu...    NaN    NaN    NaN
# Male                                                 62.1   55.6   56.8
# ...

# %%
medain_age_by_segment = fan_market_summary.iloc[49:66]
medain_age_by_segment = clean_set(medain_age_by_segment)
medain_age_by_segment
# Out:
#                                                     2011  2012  2013  2014  \
# label
# All Fans                                             NaN  44.0  42.0  42.0
# Attended at Least One NBA Game                       NaN  35.0  33.0  31.0
# Attended 4+ NBA Games                                NaN  35.0  36.0  34.0
# Viewed at Least One NBA Game On TV                   NaN  45.0  43.0  44.0
# Viewed 16+ NBA Games on TV                           NaN  45.0  43.0  44.0
# TV Viewers Who Viewed at Least One Game Traditi...   NaN   NaN   NaN   NaN
# TV Viewers Who Streamed at Least One Game to TV      NaN   NaN   NaN   NaN
# Viewed at Least One Game Online (Computer/Table...   NaN  29.0  29.0  28.0
# Followed NBA on Facebook                             NaN  30.0  31.0  31.0
# Followed NBA on Twitter                              NaN  26.0  30.0  29.0
# Purchased NBA Logo Apparel                           NaN  35.0  34.0  33.0
# ...

# %%
median_income = fan_market_summary.iloc[67:84]
median_income = clean_set(median_income)
median_income
# Out:
#                                                     2011     2012     2013  \
# label
# All Fans                                             NaN  57800.0  60200.0
# Attended at Least One NBA Game                       NaN  58200.0  69900.0
# Attended 4+ NBA Games                                NaN  46500.0  69600.0
# Viewed at Least One NBA Game on TV                   NaN  58400.0  59300.0
# Viewed 16+ NBA Games on TV                           NaN  58400.0  61600.0
# TV Viewers Who Viewed at Least One Game Traditi...   NaN      NaN      NaN
# TV Viewers Who Streamed at Least One Game to TV      NaN      NaN      NaN
# Viewed at Least One Game Online (Computer/Table...   NaN  45000.0  55900.0
# Followed NBA on Facebook                             NaN  42600.0  48700.0
# Followed NBA on Twitter                              NaN  43900.0  41900.0
# Purchased NBA Logo Apparel                           NaN  49600.0  56700.0
# ...

# %%
online_usg_by_device = fan_market_summary.iloc[85:100]
online_usg_by_device = clean_set(online_usg_by_device)
online_usg_by_device
# Out:
#                                                       2011     2012     2013  \
# label
# Total Number Using Online Device For Any Sports...     NaN  68832.0  60437.0
# Total Number Viewing at least one game on Onlin...  6255.0   7224.0   8656.0
# Total Number Using Computer for any Sports-rela...     NaN  66366.0  57121.0
# Total Number Viewing at Least One Game on Compu...  5306.0   5729.0   6989.0
# Total Number Using Tablet for any Sports-relate...     NaN  19839.0  25115.0
# Total Number Viewing at Least One Game on Table...  1478.0   1568.0   3510.0
# Total Number using Smartphone for any Sports-re...     NaN  39662.0  40991.0
# Total Number Viewing at Least One Game on Smart...  1950.0   1914.0   3019.0
# Total Number using Mobile Device for any Sports...     NaN  43658.0  46088.0
# Total Number Viewing at Least One Game on Mobil...     NaN   3059.0   4690.0
#
#                                                        2014     2015     2016  \
# label
# ...

# %%
social_media = fan_market_summary.iloc[101:109]
social_media = clean_set(social_media)
social_media
# Out:
#                                                        2011     2012     2013  \
# label
# Follow NBA on Facebook - Total all Followers (a...  17052.0  20495.0  20039.0
# Follow Facebook Daily (add 000)                      3015.0   3897.0   4101.0
# Follow Facebook 4-6 days a week (add 000)            2353.0   2282.0   2199.0
# Follow Facebook 1 to 3 days a week  (add 000)       11683.0  14316.0  13739.0
# Follow NBA on Twitter - Total all Followers (ad...   7933.0  10647.0  10278.0
# Follow Twitter Daily (add 000)                       2820.0   3628.0   3218.0
# Follow Twitter 4-6 days a week (add 000)              543.0   1289.0   1307.0
# Follow Twitter 1 to 3 days a week or less (add ...   4570.0   5730.0   5752.0
#
#                                                        2014     2015     2016  \
# label
# Follow NBA on Facebook - Total all Followers (a...  20923.0  35746.0  26513.0
# Follow Facebook Daily (add 000)                      5146.0   5828.0   4913.0
# ...

# %%
apparel_purchase = fan_market_summary.iloc[110:117]
apparel_purchase = clean_set(apparel_purchase)
apparel_purchase
# Out:
#                                                          2011      2012  \
# label
#  of All Fans Purchased Sports Logo Apparel               19.1      16.5
#  of fans who used a computer to view at least o...       50.5      40.3
#  of fans who used a Tablet to view at least one...       65.6      57.6
#  of fans who used a Smartphone to view at least...       55.7      43.6
#  of Facebook Followers Purchased Sports Logo Ap...       41.7      30.9
#  of Twitter Followers Purchased Sports Logo App...       42.9      34.3
# Expenditures for Sports Logo Apparel (add 000)      1038904.0  960616.0
#
#                                                         2013       2014  \
# label
#  of All Fans Purchased Sports Logo Apparel              18.1       19.1
#  of fans who used a computer to view at least o...      46.2       44.9
#  of fans who used a Tablet to view at least one...      49.6       54.3
#  of fans who used a Smartphone to view at least...      42.5       65.0
# ...

# %%
bball_part = fan_market_summary.iloc[118:124]
bball_part = clean_set(bball_part)
bball_part
# Out:
#                                                     2011  2012  2013  2014  \
# label
#  of all fans who participated in Basketball at ...  20.7  17.6  21.6  20.4
#  of Computer game viewers who participated in B...  42.6  36.3  48.0  48.1
#  of Tablet game viewers who participated in Bas...  53.4  31.8  43.4  46.0
#  of Smartphone game viewers who participated in...  50.5  42.0  46.6  58.0
#  of Facebook followers who participated in Bask...  35.3  32.4  35.7  32.3
#  of Twitter followers who participated in Baske...  39.2  42.1  38.8  34.9
#
#                                                     2015  2016  2017  2018  \
# label
#  of all fans who participated in Basketball at ...  20.5   NaN   NaN   NaN
#  of Computer game viewers who participated in B...  35.4   NaN   NaN   NaN
#  of Tablet game viewers who participated in Bas...  34.4   NaN   NaN   NaN
#  of Smartphone game viewers who participated in...  41.2   NaN   NaN   NaN
# ...

# %%
sports_usg = fan_market_summary.iloc[130:160]
#sports_usg = clean_set(sports_usg)
sports_usg.head()
# Out:
#                                                  label 2011              2012  \
# 133                      Total Used Social Media (Net)  NaN               NaN
# 134          ----Watch Sports-related Video on YouTube  NaN  36,048,000/42.1%
# 135  ----Used Facebook to like/follow/post about a ...  NaN  29,501,000/34.5%
# 136  ----Used Google+ to like/follow/post about a s...  NaN  20,206,000/23.6%
# 137  ----Used Instagram to like/follow/post about a...  NaN               NaN
#
#                  2013              2014              2015              2016  \
# 133               NaN  45,858,000/60.3%  56,614,000/67.4%  47,796,000/58.9%
# 134  33,582,000/45.3%  34,327,000/45.2%  40,878,000/48.7%  32,734,000/40.3%
# 135  27,166,000/36.6%  26,960,000/35.5%  37,529,000/44.7%  31,594,000/38.9%
# 136  15,309,000/20.6%  16,240,000/21.4%  19,030,000/22.7%  15,626,000/19.3%
# 137  13,999,000/18.9%  16,676,000/21.9%  20,811,000/24.8%  20,016,000/24.7%
#
# ...

# %%
influence_index = fan_market_summary.iloc[163:170]
influence_index = clean_set(influence_index)
influence_index
# Out:
#                                                     2011     2012     2013  \
# label
#  Saying Sport Sponsorship is Extremely Influential   NaN      5.9      5.4
#  Saying Sport Sponsorship is Very Influential        NaN      8.1      9.4
#  Saying Sport Sponsorship is Moderately Influen...   NaN     19.3     17.7
#  Saying Sport Sponsorship is Slightly Influential    NaN     17.1     17.2
#  Saying Sport Sponsorship is Not at All Influen...   NaN     49.7     50.3
# Total                                                NaN    100.0    100.0
# Base (Total No. of NBA Fans - add 000)               NaN  85556.0  74187.0
#
#                                                        2014     2015     2016  \
# label
#  Saying Sport Sponsorship is Extremely Influential      7.3     10.7      7.9
#  Saying Sport Sponsorship is Very Influential          10.2     16.1     10.3
#  Saying Sport Sponsorship is Moderately Influen...     18.4     19.5     18.9
# ...

# %%
gender_index = fan_market_summary.iloc[173:175]
gender_index = clean_set(gender_index)
gender_index
# Out:
#         2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# label
# Male     NaN  114.0   98.0  106.0  105.0  105.0  100.0  104.0  102.0  109.0
# Female   NaN   82.0  108.0   92.0   92.0   93.0  100.0   95.0   97.0   85.0

# %%
age_index = fan_market_summary.iloc[176:181]
age_index = clean_set(age_index)
age_index
# Out:
#        2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# label
# 13-17   NaN  197.0  176.0  147.0  143.0  151.0  155.0  129.0  124.0  119.0
# 18-24   NaN  210.0  106.0  103.0  140.0  179.0  171.0  238.0  197.0  136.0
# 25-34   NaN  113.0  138.0  122.0  120.0  147.0  165.0  153.0  199.0  143.0
# 35-49   NaN  115.0   99.0  115.0  112.0  105.0  109.0  121.0   80.0    1.9
# 50+     NaN   42.0   66.0   71.0   62.0   54.0   48.0   42.0   48.0   58.0

# %%
age_index.reset_index()
# Out:
#    label  2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 0  13-17   NaN  197.0  176.0  147.0  143.0  151.0  155.0  129.0  124.0  119.0
# 1  18-24   NaN  210.0  106.0  103.0  140.0  179.0  171.0  238.0  197.0  136.0
# 2  25-34   NaN  113.0  138.0  122.0  120.0  147.0  165.0  153.0  199.0  143.0
# 3  35-49   NaN  115.0   99.0  115.0  112.0  105.0  109.0  121.0   80.0    1.9
# 4    50+   NaN   42.0   66.0   71.0   62.0   54.0   48.0   42.0   48.0   58.0

# %%
age_index_reset=age_index.reset_index()

# %%
age_index_pd.rename(columns={"label":"age"}) ,inplace=True
#df.rename(columns={"A": "a", "B": "c"})
# Out:
#   File "<ipython-input-229-e6c69e7a9b52>", line 1
#     age_index_pd.rename(columns={"label":"age"}) ,inplace=True
#     ^
# SyntaxError: cannot assign to function call

# %%
#df = px.data.iris() # iris is a pandas DataFrame
fig = px.line(age_index_reset,x='label', y=['2016','2017','2018','2019','2020'])
           


fig.show()
# Out:
# <div>                            <div id="10df6659-0b99-4c17-89a3-8659d1556685" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10df6659-0b99-4c17-89a3-8659d1556685")) {                    Plotly.newPlot(                        "10df6659-0b99-4c17-89a3-8659d1556685",                        [{"hovertemplate":"variable=2016<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"type":"scatter","x":["13-17","18-24","25-34","35-49","50+"],"xaxis":"x","y":[151.0,179.0,147.0,105.0,54.0],"yaxis":"y"},{"hovertemplate":"variable=2017<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"mo
# ...

# %%
  fig.update_layout(
    title="Fan Market Ages",
    xaxis_title="Age Ranges",
    yaxis_title="Number of Fans",
    legend_title="Year")
# Out:
# <div>                            <div id="e1d9b63a-cd97-4c4d-992b-61f555c64ebd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1d9b63a-cd97-4c4d-992b-61f555c64ebd")) {                    Plotly.newPlot(                        "e1d9b63a-cd97-4c4d-992b-61f555c64ebd",                        [{"hovertemplate":"variable=2016<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"type":"scatter","x":["13-17","18-24","25-34","35-49","50+"],"xaxis":"x","y":[151.0,179.0,147.0,105.0,54.0],"yaxis":"y"},{"hovertemplate":"variable=2017<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"mo
# ...

# %%
generation_index = fan_market_summary.iloc[182:186]
generation_index = clean_set(generation_index)
generation_index
# Out:
#                       2011  2012  2013  2014  2015  2016  2017  2018   2019  \
# label
# Generation Z (13-22)   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  175.0
# Millennials (23-38)    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  166.0
# Generation X (39-54)   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   73.0
# Boomers (55-73)        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   47.0
#
#                        2020
# label
# Generation Z (13-22)  128.0
# Millennials (23-38)   137.0
# Generation X (39-54)   92.0
# Boomers (55-73)        60.0

# %%
region_index = fan_market_summary.iloc[187:191]
region_index = clean_set(region_index)
region_index
# Out:
#            2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# label
# Northeast   NaN   81.0  103.0  118.0  102.0  118.0   94.0   85.0   74.0   97.0
# Midwest     NaN   79.0   86.0   62.0   87.0  106.0   83.0   90.0   93.0   79.0
# South       NaN  128.0  107.0  110.0  101.0  114.0  116.0  106.0  111.0  117.0
# West        NaN   89.0   97.0  112.0  108.0   66.0   97.0   90.0  104.0   96.0

# %%
region_reset=region_index.reset_index()

# %%
#df = px.data.iris() # iris is a pandas DataFrame
fig = px.line(region_reset, x='label', y=['2015','2016','2017','2018','2019','2020'])

fig.show()
# Out:
# <div>                            <div id="9ca532da-c8c7-4c44-920f-2297001f67ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ca532da-c8c7-4c44-920f-2297001f67ec")) {                    Plotly.newPlot(                        "9ca532da-c8c7-4c44-920f-2297001f67ec",                        [{"hovertemplate":"variable=2015<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2015","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2015","orientation":"v","showlegend":true,"type":"scatter","x":["Northeast","Midwest","South","West"],"xaxis":"x","y":[102.0,87.0,101.0,108.0],"yaxis":"y"},{"hovertemplate":"variable=2016<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#EF553B","dash":"solid"},"mode":"li
# ...

# %%
  fig.update_layout(
    title="Fan Market Regions",
    xaxis_title="Regions",
    yaxis_title="Number of Fans",
    legend_title="Year")
# Out:
# <div>                            <div id="d762bc1b-16ac-403d-b535-2b50d28c7bfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d762bc1b-16ac-403d-b535-2b50d28c7bfa")) {                    Plotly.newPlot(                        "d762bc1b-16ac-403d-b535-2b50d28c7bfa",                        [{"hovertemplate":"variable=2015<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2015","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2015","orientation":"v","showlegend":true,"type":"scatter","x":["Northeast","Midwest","South","West"],"xaxis":"x","y":[102.0,87.0,101.0,108.0],"yaxis":"y"},{"hovertemplate":"variable=2016<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#EF553B","dash":"solid"},"mode":"li
# ...

# %%
income_index = fan_market_summary.iloc[192:196]
income_index = clean_set(income_index)
income_index
# Out:
#                 2011   2012   2013   2014   2015   2016   2017   2018   2019  \
# label
# Under 25000      NaN  133.0  114.0   77.0  111.0  162.0  146.0  128.0  117.0
# 25000-49999      NaN  148.0  117.0  136.0   96.0  117.0  131.0  119.0  135.0
# 50000-99999      NaN   89.0   85.0  101.0   98.0   90.0   90.0  100.0  105.0
# 100000 or more   NaN   41.0   92.0   85.0   99.0   66.0   75.0   81.0   75.0
#
#                  2020
# label
# Under 25000       1.9
# 25000-49999     115.0
# 50000-99999      80.0
# 100000 or more  104.0

# %%
income_reset.head()
# Out:
#             label  2011   2012   2013   2014   2015   2016   2017   2018  \
# 0     Under 25000   NaN  133.0  114.0   77.0  111.0  162.0  146.0  128.0
# 1     25000-49999   NaN  148.0  117.0  136.0   96.0  117.0  131.0  119.0
# 2     50000-99999   NaN   89.0   85.0  101.0   98.0   90.0   90.0  100.0
# 3  100000 or more   NaN   41.0   92.0   85.0   99.0   66.0   75.0   81.0
#
#     2019   2020
# 0  117.0    1.9
# 1  135.0  115.0
# 2  105.0   80.0
# 3   75.0  104.0

# %%
income_reset.dtypes
# Out:
# label    float64
# 2011     float64
# 2012     float64
# 2013     float64
# 2014     float64
# 2015     float64
# 2016     float64
# 2017     float64
# 2018     float64
# 2019     float64
# 2020     float64
# dtype: object

# %%
#players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]] = 
#players_salaries_endorsements[["salaries in 2021","Endorsements Earnings in 2021"]]
#.apply(lambda x: x.str.replace(',', ''), axis=1).apply(lambda x: x.str.replace('$', ''), axis=1).
#apply(lambda x: x.astype(float), axis=1)
income_reset[['label']]=income_reset[['label']].apply(lambda x: (isinstance(x, str)))

# %%
income_reset["label"] = pd.to_numeric(income_reset["label"])

# %%
fig = px.line(income_reset, y=['2015','2016','2017','2018','2019','2020'])

fig.show()
# Out:
# <div>                            <div id="17c025f0-1c1a-4598-8eda-6fb651e32c33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17c025f0-1c1a-4598-8eda-6fb651e32c33")) {                    Plotly.newPlot(                        "17c025f0-1c1a-4598-8eda-6fb651e32c33",                        [{"hovertemplate":"variable=2015<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2015","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2015","orientation":"v","showlegend":true,"type":"scatter","x":[0,1,2,3],"xaxis":"x","y":[111.0,96.0,98.0,99.0],"yaxis":"y"},{"hovertemplate":"variable=2016<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"2016","orientation
# ...

# %%
  fig.update_layout(
  
    title="Fan Market Income",
    xaxis_title="Age Ranges",
    yaxis_title="Number of Fans",
    legend_title="Year")
# Out:
# <div>                            <div id="2e4e7914-b9b5-4260-b733-edd595ca760e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e4e7914-b9b5-4260-b733-edd595ca760e")) {                    Plotly.newPlot(                        "2e4e7914-b9b5-4260-b733-edd595ca760e",                        [{"hovertemplate":"variable=2015<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2015","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2015","orientation":"v","showlegend":true,"type":"scatter","x":[0,1,2,3],"xaxis":"x","y":[111.0,96.0,98.0,99.0],"yaxis":"y"},{"hovertemplate":"variable=2016<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"2016","orientation
# ...

# %%
education_index = fan_market_summary.iloc[197:202]
education_index = clean_set(education_index)
education_index
# Out:
#                                2011  2012  2013  2014  2015  2016  2017  \
# label
# Some High School or less        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# High School Graduate            NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Some College/Technical School   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Graduate College                NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Post Graduate Work or Degree    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                                 2018   2019   2020
# label
# Some High School or less       133.0  140.0  117.0
# High School Graduate           133.0  141.0  124.0
# Some College/Technical School   96.0  122.0   97.0
# Graduate College                94.0   95.0   89.0
# Post Graduate Work or Degree    85.0   73.0    1.2

# %%
education_index.reset_index()
# Out:
#                            label  2011  2012  2013  2014  2015  2016  2017  \
# 0       Some High School or less   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1           High School Graduate   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  Some College/Technical School   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Graduate College   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   Post Graduate Work or Degree   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     2018   2019   2020
# 0  133.0  140.0  117.0
# 1  133.0  141.0  124.0
# 2   96.0  122.0   97.0
# 3   94.0   95.0   89.0
# 4   85.0   73.0    1.2

# %%
education_reset=education_index.reset_index()

# %%
fig = px.line(education_reset, x='label', y=['2018','2019','2020'])

fig.show()
# Out:
# <div>                            <div id="73947c8c-6ac4-4ea5-a494-b4b57bb9513f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73947c8c-6ac4-4ea5-a494-b4b57bb9513f")) {                    Plotly.newPlot(                        "73947c8c-6ac4-4ea5-a494-b4b57bb9513f",                        [{"hovertemplate":"variable=2018<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"type":"scatter","x":["Some High School or less","High School Graduate","Some College/Technical School","Graduate College","Post Graduate Work or Degree"],"xaxis":"x","y":[133.0,133.0,96.0,94.0,85.0],"yaxis":"y"},{"hovertemplate":"variable=2019<br>label=%{x}<br>v
# ...

# %%
  fig.update_layout(
  
    title="Fan Market Education",
    xaxis_title="Education Level",
    yaxis_title="Number of Fans per Education Level",
    legend_title="Year")
# Out:
# <div>                            <div id="235f3743-111f-41bf-9293-504bc67087bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("235f3743-111f-41bf-9293-504bc67087bf")) {                    Plotly.newPlot(                        "235f3743-111f-41bf-9293-504bc67087bf",                        [{"hovertemplate":"variable=2018<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"type":"scatter","x":["Some High School or less","High School Graduate","Some College/Technical School","Graduate College","Post Graduate Work or Degree"],"xaxis":"x","y":[133.0,133.0,96.0,94.0,85.0],"yaxis":"y"},{"hovertemplate":"variable=2019<br>label=%{x}<br>v
# ...

# %% [markdown]
# ## Section 2: Player Stats Hypotheses
# By Jamila Smith-Dell

# %% [markdown]
# ### Random Sampling of 100 players (used in Hypothesis Testing Section 1 and Section 2 and the rest of the project analysis)

# %%
player_stats_2020_2021 = pd.read_csv('2020-2021 NBA Player Stats.csv')
player_stats_2020_2021.head()
# Out:
#    Rk                       Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1   Precious Achiuwa\achiupr01  PF   21  MIA  61   4   737  124  228  ...
# 1   2       Jaylen Adams\adamsja01  PG   24  MIL   7   0    18    1    8  ...
# 2   3       Steven Adams\adamsst01   C   27  NOP  58  58  1605  189  308  ...
# 3   4        Bam Adebayo\adebaba01   C   23  MIA  64  64  2143  456  800  ...
# 4   5  LaMarcus Aldridge\aldrila01   C   35  TOT  26  23   674  140  296  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.509   73  135  208   29   20   28   43   91   304
# 1    NaN    0    3    3    2    0    0    0    1     2
# 2  0.444  213  301  514  111   54   38   78  113   438
# 3  0.799  142  431  573  346   75   66  169  145  1197
# 4  0.872   19   99  118   49   11   29   27   47   352
#
# [5 rows x 30 columns]

# %%
player_stats_2020_2021.shape
# Out:
# (705, 30)

# %%
player_stats_2020_2021.loc[(player_stats_2020_2021.Age >19 ),  'AgeGroup'] = 'ages 19-23'
player_stats_2020_2021.loc[(player_stats_2020_2021.Age >24 ),  'AgeGroup'] = 'ages 24-28'
player_stats_2020_2021.loc[(player_stats_2020_2021.Age >29 ),  'AgeGroup'] = 'ages 29-33'
player_stats_2020_2021.loc[(player_stats_2020_2021.Age > 34 ),  'AgeGroup'] = 'ages 34-40'
player_stats_2020_2021.loc[(player_stats_2020_2021.Age > 40),  'AgeGroup'] = 'ages 40+'

# %%
player_stats_2020_2021[['AgeGroup','Age']].groupby("AgeGroup").count()
player_count= player_stats_2020_2021[['AgeGroup','Age']].groupby("AgeGroup").count()

# %%
player_count.columns
# Out:
# Index(['Age'], dtype='object')

# %%
player_count=player_count.reset_index()

# %%
player_stats_2020_2021.head()
# Out:
#    Rk                       Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1   Precious Achiuwa\achiupr01  PF   21  MIA  61   4   737  124  228  ...
# 1   2       Jaylen Adams\adamsja01  PG   24  MIL   7   0    18    1    8  ...
# 2   3       Steven Adams\adamsst01   C   27  NOP  58  58  1605  189  308  ...
# 3   4        Bam Adebayo\adebaba01   C   23  MIA  64  64  2143  456  800  ...
# 4   5  LaMarcus Aldridge\aldrila01   C   35  TOT  26  23   674  140  296  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS    AgeGroup
# 0   73  135  208   29   20   28   43   91   304  ages 19-23
# 1    0    3    3    2    0    0    0    1     2  ages 19-23
# 2  213  301  514  111   54   38   78  113   438  ages 24-28
# 3  142  431  573  346   75   66  169  145  1197  ages 19-23
# 4   19   99  118   49   11   29   27   47   352  ages 34-40
#
# [5 rows x 31 columns]

# %%
import plotly.express as px

df= player_stats_2020_2021
fig = px.pie(player_count,values='Age', names='AgeGroup', title='NBA Players Ages',
            color_discrete_sequence=px.colors.sequential.Bluered)
fig.show()
# Out:
# <div>                            <div id="dd081239-ae41-4f91-b500-87eecb87055e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd081239-ae41-4f91-b500-87eecb87055e")) {                    Plotly.newPlot(                        "dd081239-ae41-4f91-b500-87eecb87055e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"AgeGroup=%{label}<br>Age=%{value}<extra></extra>","labels":["ages 19-23","ages 24-28","ages 29-33","ages 34-40"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[287,258,123,22]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(0,0,255)","rgb(255,0,0)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"colo
# ...

# %%
player_stats_2020_2021.shape
# Out:
# (705, 31)

# %%
player_stats_2020_2021['Player'].value_counts()
# Out:
# Norvel Pelle           4
# Rodions Kurucs         4
# Gary Clark             4
# Victor Oladipo         4
# Moritz Wagner          4
#                       ..
# Malcolm Brogdon        1
# Justin Holiday         1
# Talen Horton-Tucker    1
# Derrick Jones Jr.      1
# Cam Reddish            1
# Name: Player, Length: 540, dtype: int64

# %%
player_stats_2020_2021['Player'] = player_stats_2020_2021['Player'].str.split(pat= '\\', expand = True)[0]

# %%
player_stats_2020_2021['Player'].value_counts()
# Out:
# Norvel Pelle           4
# Rodions Kurucs         4
# Gary Clark             4
# Victor Oladipo         4
# Moritz Wagner          4
#                       ..
# Malcolm Brogdon        1
# Justin Holiday         1
# Talen Horton-Tucker    1
# Derrick Jones Jr.      1
# Cam Reddish            1
# Name: Player, Length: 540, dtype: int64

# %%
player_stats_2020_2021_sample = player_stats_2020_2021.sample(100, random_state=77)

# %%
player_stats_2020_2021_sample.head()
# Out:
#       Rk           Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  ORB  \
# 601  464      Jalen Smith  PF   20  PHO  27   1   156   22   50  ...    7
# 625  481      Matt Thomas  SG   26  TOR  26   0   192   24   62  ...    3
# 20    15  Carmelo Anthony  PF   36  POR  69   3  1690  327  777  ...   32
# 368  278     John Konchar  SG   24  MEM  43   0   575   69  138  ...   35
# 139  109       Tyler Cook  PF   23  BRK   4   0    17    1    3  ...    1
#
#      DRB  TRB  AST  STL  BLK  TOV   PF  PTS    AgeGroup
# 601   30   37    4    1    5    7   16   53  ages 19-23
# 625   18   21    9    2    0    6   10   71  ages 24-28
# 20   182  214  104   46   38   61  144  924  ages 34-40
# 368   93  128   47   30    9   18   40  184  ages 19-23
# 139    1    2    2    0    0    1    2    2  ages 19-23
#
# [5 rows x 31 columns]

# %%
pd.set_option('display.max_rows', 100)
player_stats_2020_2021_sample
# Out:
#       Rk                 Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 601  464            Jalen Smith  PF   20  PHO  27   1   156   22    50  ...
# 625  481            Matt Thomas  SG   26  TOR  26   0   192   24    62  ...
# 20    15        Carmelo Anthony  PF   36  POR  69   3  1690  327   777  ...
# 368  278           John Konchar  SG   24  MEM  43   0   575   69   138  ...
# 139  109             Tyler Cook  PF   23  BRK   4   0    17    1     3  ...
# 77    62           Tony Bradley   C   23  TOT  42   8   684  131   197  ...
# 517  400           Norvel Pelle   C   27  NYK   9   0    52    5     7  ...
# 17    12  Giannis Antetokounmpo  PF   26  MIL  61  61  2013  626  1100  ...
# 279  212           Jaxson Hayes   C   20  NOP  60   3   964  175   280  ...
# 100   78          Jalen Brunson  PG   24  DAL  68  12  1697  328   627  ...
# 120   96            Alex Caruso  PG   26  LAL  58   6  1216  133   305  ...
# ...

# %%
player_stats_2020_2021_sample.loc[(player_stats_2020_2021.Age >19 ),  'AgeGroup'] = 'ages 19-23'
player_stats_2020_2021_sample.loc[(player_stats_2020_2021.Age >24 ),  'AgeGroup'] = 'ages 24-28'
player_stats_2020_2021_sample.loc[(player_stats_2020_2021.Age >29 ),  'AgeGroup'] = 'ages 29-33'
player_stats_2020_2021_sample.loc[(player_stats_2020_2021.Age > 34 ),  'AgeGroup'] = 'ages 34-40'
player_stats_2020_2021_sample.loc[(player_stats_2020_2021.Age > 40 ),  'AgeGroup'] = 'ages 40 and up'

# %%
player_stats_2020_2021_sample[['AgeGroup','Age']].groupby("AgeGroup").count()
player_counts= player_stats_2020_2021_sample[['AgeGroup','Age']].groupby("AgeGroup").count()

# %%
player_counts=player_counts.reset_index()

# %%
player_counts.head()
# Out:
#      AgeGroup  Age
# 0  ages 19-23   42
# 1  ages 24-28   38
# 2  ages 29-33   14
# 3  ages 34-40    4

# %%
player_stats_2020_2021_sample.head()
# Out:
#       Rk           Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  ORB  \
# 601  464      Jalen Smith  PF   20  PHO  27   1   156   22   50  ...    7
# 625  481      Matt Thomas  SG   26  TOR  26   0   192   24   62  ...    3
# 20    15  Carmelo Anthony  PF   36  POR  69   3  1690  327  777  ...   32
# 368  278     John Konchar  SG   24  MEM  43   0   575   69  138  ...   35
# 139  109       Tyler Cook  PF   23  BRK   4   0    17    1    3  ...    1
#
#      DRB  TRB  AST  STL  BLK  TOV   PF  PTS    AgeGroup
# 601   30   37    4    1    5    7   16   53  ages 19-23
# 625   18   21    9    2    0    6   10   71  ages 24-28
# 20   182  214  104   46   38   61  144  924  ages 34-40
# 368   93  128   47   30    9   18   40  184  ages 19-23
# 139    1    2    2    0    0    1    2    2  ages 19-23
#
# [5 rows x 31 columns]

# %%
import plotly.express as px

df= player_stats_2020_2021_sample
fig = px.pie(player_counts,values='Age', names='AgeGroup', title='NBA Players Ages',
            color_discrete_sequence=px.colors.sequential.Bluered)
fig.show()
# Out:
# <div>                            <div id="cedd69fb-151b-4240-8eb1-ad42e2815e58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cedd69fb-151b-4240-8eb1-ad42e2815e58")) {                    Plotly.newPlot(                        "cedd69fb-151b-4240-8eb1-ad42e2815e58",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"AgeGroup=%{label}<br>Age=%{value}<extra></extra>","labels":["ages 19-23","ages 24-28","ages 29-33","ages 34-40"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[42,38,14,4]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(0,0,255)","rgb(255,0,0)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"
# ...

# %%
endorsements = pd.read_csv("c_endorsements2.csv")
endorsements.rename({"Unnamed: 0":"player"}, axis=1, inplace=True)
#endorsements.set_index('player', inplace=True)
endorsements.head()
# Out:
#                   player  endorsement  twitter_follows  min_cost_post  \
# 0           James Harden         17.0            6.500        27000.0
# 1  Giannis Antetokounmpo         19.0            0.817         9000.0
# 2         Damian Lillard         13.0            1.800        13500.0
# 3            Paul George          8.0            2.200         9000.0
# 4           Kevin Durant         35.0           17.900        67500.0
#
#    max_cost_post  avg_cost  value_post  value_cost                    team  \
# 0        37500.0   32250.0     69504.0    2.155163         Houston Rockets
# 1        12500.0   10750.0     10779.0    1.002698          Milwauke Bucks
# 2        18750.0   16125.0     19299.0    1.196837  Portland Trail Blazers
# 3        12500.0   10750.0     23469.0    2.183163   oklahoma City Thunder
# 4        93750.0   80625.0    190464.0    2.362344           Brooklyn Nets
#
#     division  ...     PF     PTS  percent_2P  percent_3P  percent_eFG  \
# ...

# %%
data = endorsements.iloc[:, 15:25]





data.head()
# Out:
#    shooting_percent    ORB    DRB    TRB    AST    STL    BLK    TOV     PF  \
# 0             0.616   66.0  452.0  518.0  586.0  158.0   58.0  387.0  244.0
# 1             0.644  159.0  739.0  898.0  424.0   92.0  110.0  268.0  232.0
# 2             0.588   68.0  303.0  371.0  551.0   88.0   34.0  212.0  148.0
# 3           583.000  105.0  523.0  628.0  318.0  170.0   34.0  205.0  214.0
# 4             0.631   33.0  464.0  497.0  457.0   58.0   84.0  225.0  155.0
#
#       PTS
# 0  2818.0
# 1  1994.0
# 2  2067.0
# 3  2159.0
# 4  2027.0

# %%
data["minute_played"] = endorsements["minute_played"]

# %%
data["player"] = endorsements["player"]

# %%
data.head()
# Out:
#    shooting_percent    ORB    DRB    TRB    AST    STL    BLK    TOV     PF  \
# 0             0.616   66.0  452.0  518.0  586.0  158.0   58.0  387.0  244.0
# 1             0.644  159.0  739.0  898.0  424.0   92.0  110.0  268.0  232.0
# 2             0.588   68.0  303.0  371.0  551.0   88.0   34.0  212.0  148.0
# 3           583.000  105.0  523.0  628.0  318.0  170.0   34.0  205.0  214.0
# 4             0.631   33.0  464.0  497.0  457.0   58.0   84.0  225.0  155.0
#
#       PTS  minute_played                 player
# 0  2818.0         2867.0           James Harden
# 1  1994.0         2358.0  Giannis Antetokounmpo
# 2  2067.0         2838.0         Damian Lillard
# 3  2159.0         2841.0            Paul George
# 4  2027.0         2702.0           Kevin Durant

# %%
df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(data, x='ORB', y='DRB',
                 color= "DRB",color_continuous_scale='bluered',
                
    title="Defensive vs Offensive Rebounds",
    
    )

fig.show()
# Out:
# <div>                            <div id="a507ad03-b47c-4262-a95a-8600b1439169" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a507ad03-b47c-4262-a95a-8600b1439169")) {                    Plotly.newPlot(                        "a507ad03-b47c-4262-a95a-8600b1439169",                        [{"hovertemplate":"ORB=%{x}<br>DRB=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[452.0,739.0,303.0,523.0,464.0,809.0,324.0,498.0,361.0,264.0,369.0,711.0,465.0,199.0,322.0,338.0,408.0,698.0,229.0,271.0,408.0,560.0,352.0,547.0,220.0,259.0,262.0,271.0,304.0,260.0,206.0,59.0,269.0,45.0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[66.0,159.0,68.0,105.0,33.0,423.0,
# ...

# %%
df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(data, x='AST', y='TOV',
                 color= "TOV",color_continuous_scale='bluered',
                 title="Assists vs Turnovers "
                )

fig.show()
# Out:
# <div>                            <div id="27adc010-cf8d-47c3-bc4d-3019f2d4cd71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27adc010-cf8d-47c3-bc4d-3019f2d4cd71")) {                    Plotly.newPlot(                        "27adc010-cf8d-47c3-bc4d-3019f2d4cd71",                        [{"hovertemplate":"AST=%{x}<br>TOV=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[387.0,268.0,212.0,205.0,225.0,175.0,192.0,112.0,121.0,172.0,135.0,226.0,253.0,130.0,224.0,102.0,197.0,325.0,152.0,182.0,199.0,97.0,95.0,155.0,106.0,210.0,115.0,105.0,98.0,65.0,42.0,16.0,138.0,8.0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[586.0,424.0,551.0,318.0,457.0,112.0,361
# ...

# %%
df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(data, x='STL', y='BLK',
                 color= "BLK",color_continuous_scale='bluered',
                title="Steals vs Blocks")

fig.show()
# Out:
# <div>                            <div id="8e938898-7a92-45ac-bc66-246b01ef26a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e938898-7a92-45ac-bc66-246b01ef26a8")) {                    Plotly.newPlot(                        "8e938898-7a92-45ac-bc66-246b01ef26a8",                        [{"hovertemplate":"STL=%{x}<br>BLK=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[58.0,110.0,34.0,34.0,84.0,138.0,25.0,135.0,24.0,34.0,76.0,122.0,28.0,22.0,58.0,86.0,33.0,33.0,18.0,31.0,36.0,136.0,54.0,86.0,28.0,54.0,47.0,23.0,13.0,31.0,5.0,4.0,48.0,7.0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[158.0,92.0,88.0,170.0,58.0,136.0,92.0,88.0,106.0,103.0,117.0,46
# ...

# %%
df = px.data.iris() # iris is a pandas DataFrame
fig = px.scatter(data, x='PTS', y='minute_played',
                 color= "minute_played",color_continuous_scale='bluered',
                title="Points vs Minutes Played")

fig.show()
# Out:
# <div>                            <div id="59a19de6-0919-43f6-b068-653415f6b0e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59a19de6-0919-43f6-b068-653415f6b0e3")) {                    Plotly.newPlot(                        "59a19de6-0919-43f6-b068-653415f6b0e3",                        [{"hovertemplate":"PTS=%{x}<br>minute_played=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2867.0,2358.0,2838.0,2841.0,2702.0,2647.0,2331.0,1850.0,2040.0,2214.0,2669.0,2154.0,2622.0,2342.0,3028.0,1973.0,1937.0,2630.0,1857.0,2213.0,2688.0,1674.0,1895.0,2436.0,2375.0,2402.0,2652.0,1863.0,2533.0,1683.0,598.0,230.0,2543.0,294.0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scat
# ...

# %%
import plotly.express as px
#df = px.data.iris()
fig = px.scatter_matrix(data, dimensions=['TOV','BLK','ORB','minute_played','DRB'],
    color="player")
fig.show()
# Out:
# <div>                            <div id="523628c1-634d-4596-b84c-14d41ea1330b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("523628c1-634d-4596-b84c-14d41ea1330b")) {                    Plotly.newPlot(                        "523628c1-634d-4596-b84c-14d41ea1330b",                        [{"dimensions":[{"axis":{"matches":true},"label":"TOV","values":[387.0]},{"axis":{"matches":true},"label":"BLK","values":[58.0]},{"axis":{"matches":true},"label":"ORB","values":[66.0]},{"axis":{"matches":true},"label":"minute_played","values":[2867.0]},{"axis":{"matches":true},"label":"DRB","values":[452.0]}],"hovertemplate":"player=James Harden<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"James Harden","marker":{"color":"
# ...
